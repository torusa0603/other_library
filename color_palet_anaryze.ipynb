        (0xff,0xf2,0x85),(0xff,0xf2,0x8a),(0xff,0xf3,0x8e),(0xff,0xf4,0x92),(0xff,0xf4,0x96),(0xff,0xf4,0x9a),(0xff,0xf5,0x9e),(0xff,0xf5,0xa2),(0xff,0xf5,0xa6),(0xff,0xf6,0xaa),(0xff,0xf6,0xaf),(0xff,0xf7,0xb3),(0xff,0xf7,0xb6),(0xff,0xf8,0xba),(0xff,0xf8,0xbd),(0xff,0xf8,0xc1),
        (0xff,0xf8,0xc4),(0xff,0xf9,0xc7),(0xff,0xf9,0xca),(0xff,0xf9,0xcd),(0xff,0xfa,0xd1),(0xff,0xfa,0xd4),(0xff,0xfb,0xd8),(0xff,0xfc,0xdb),(0xff,0xfc,0xdf),(0xff,0xfd,0xe2),(0xff,0xfd,0xe5),(0xff,0xfd,0xe8),(0xff,0xfe,0xeb),(0xff,0xfe,0xee),(0xff,0xfe,0xf1),(0xff,0xfe,0xf4),
        (0xff,0xff,0xf6)
    ]

lit_r = [r[0] for r in iron_palet]
lit_r_cut = [0] * 50
lit_r_cut.extend(lit_r[50:200])
lit_g = [r[1] for r in iron_palet]
lit_g_cut = [0] * 200
lit_g_cut.extend(lit_g[200:])
lit_b = [r[2] for r in iron_palet]
lit_b_cut = lit_b[:50]
lit_sum = [(r[0] + r[1] + r[2]) for r in iron_palet]


plt.plot(lit_r, color = "red")
plt.plot(lit_g, color = "green")
plt.plot(lit_b, color = "blue")
plt.plot(lit_sum, color = "black")
plt.show()

lit_r_b = [(r[0] - r[2]) for r in iron_palet]
lit_r_g = [(r[0] - r[1]) for r in iron_palet]
lit_g_b = [(r[1] - r[2]) for r in iron_palet]

plt.plot(lit_r_b, color = "magenta")
plt.plot(lit_r_g, color = "cyan")
plt.plot(lit_g_b, color = "yellow")
plt.show()

# %%
plt.plot(lit_r, lit_g, color = "red")
plt.show()
plt.plot(lit_b, lit_g, color = "green")
plt.show()
plt.plot(lit_r, lit_b, color = "blue")
plt.show()

# %%
plt.plot(lit_r_cut, color = (1,0,0,0.5)) #Rが50以下
plt.plot(lit_g_cut, color = (0,1,0,0.5)) #B-Gが正の時
plt.plot(lit_b_cut, color = (0,0,1,0.5)) #それ以降
plt.show()

# %%
x_r = np.array(range(len(lit_r_cut[50:]))).reshape(-1,1)
y_r = np.array(lit_r_cut[50:]).reshape(-1,1)
model_lr_r = LinearRegression()
model_lr_r.fit(x_r, y_r)

x_g = np.array(range(len(lit_g_cut[200:]))).reshape(-1,1)
y_g = np.array(lit_g_cut[200:]).reshape(-1,1)
model_lr_g = LinearRegression()
model_lr_g.fit(x_g, y_g)

x_b = np.array(range(len(lit_b_cut))).reshape(-1,1)
y_b = np.array(lit_b_cut).reshape(-1,1)
model_lr_b = LinearRegression()
model_lr_b.fit(x_b, y_b)

plt.plot(x_r, model_lr_r.predict(x_r), linestyle="solid",color = (1,0,0,0.5))
plt.plot(x_g, model_lr_g.predict(x_g), linestyle="solid",color = (0,1,0,0.5))
plt.plot(x_b, model_lr_b.predict(x_b), linestyle="solid",color = (0,0,1,0.5))
plt.plot(lit_r_cut[50:], color = "red")
plt.plot(lit_g_cut[200:], color = "green")
plt.plot(lit_b_cut, color = "blue")
plt.show()

print('y= %.3fx + %.3f' % (model_lr_r.coef_ , model_lr_r.intercept_))
print('決定係数 R^2: ', model_lr_r.score(x_r, y_r))
print('')
print('y= %.3fx + %.3f' % (model_lr_g.coef_ , model_lr_g.intercept_))
print('決定係数 R^2: ', model_lr_g.score(x_g, y_g))
print('')
print('y= %.3fx + %.3f' % (model_lr_b.coef_ , model_lr_b.intercept_))
print('決定係数 R^2: ', model_lr_b.score(x_b, y_b))
# Out:
# y= 1.184x + 66.074
# 決定係数 R^2:  0.9608629527744935
#
# y= 0.930x + 58.260
# 決定係数 R^2:  0.9899783462089007
#
# y= 2.288x + 41.111
# 決定係数 R^2:  0.9235878477677917

# %%
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
#ax=Axes3D(fig)
ax=fig.add_subplot(projection='3d')

ax.scatter3D(lit_r, lit_g, lit_b)
ax.set_xlabel("R")
ax.set_ylabel("G")
ax.set_zlabel("B")

plt.show()

# %%
import math

def calc_logarithm(n):
  ret = math.log((n + 1), 2)
  return int(ret)

def calc_index(n):
  ret = (2)**n
  return int(1 / ret)

lit_r_calc_logarithm = list(map(calc_logarithm, lit_r))
lit_r_calc_index = list(map(calc_index, lit_r))
plt.plot(lit_r_calc_logarithm, color = "black")
plt.plot(lit_r_calc_index, color = "red")
plt.show()

# %%
import colorsys

lit_hsv  = [colorsys.rgb_to_hsv(r[0]/255, r[1]/255, r[2]/255) for r in iron_palet]

lit_h = [r[0]*360 for r in lit_hsv]
lit_s = [r[1]*100 for r in lit_hsv]
lit_v = [r[2]*100 for r in lit_hsv]

plt.plot(lit_h, color = "red")
plt.plot(lit_s, color = "green")
plt.plot(lit_v, color = "blue")
plt.show()

# %%
border = 203
lit_h_front = lit_h[:border]
lit_h_back = lit_h[border:]
lit_h_back_cut = lit_h[border:(border + 200)]

plt.plot(lit_h_front, color = "red")
plt.plot(lit_h_back, color = "red")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

x = np.array(range(len(lit_h_front))).reshape(-1,1)
y = np.array(lit_h_front).reshape(-1,1)
model_lr = LinearRegression()
model_lr.fit(x, y)

plt.plot(x, model_lr.predict(x), linestyle="solid")
plt.plot(lit_h_front, color = "red")
plt.show()

print('モデル関数の回帰変数 w1: %.3f' %model_lr.coef_)
print('モデル関数の切片 w2: %.3f' %model_lr.intercept_)
print('y= %.3fx + %.3f' % (model_lr.coef_ , model_lr.intercept_))
print('決定係数 R^2: ', model_lr.score(x, y))
# Out:
# モデル関数の回帰変数 w1: 0.571
# モデル関数の切片 w2: 232.366
# y= 0.571x + 232.366
# 決定係数 R^2:  0.9929930580923619

# %%
x = np.array(range(len(lit_h_back))).reshape(-1,1)
y = np.array(lit_h_back).reshape(-1,1)
model_lr = LinearRegression()
model_lr.fit(x, y)

x_cut = np.array(range(len(lit_h_back_cut))).reshape(-1,1)
y_cut = np.array(lit_h_back_cut).reshape(-1,1)
model_lr_cut = LinearRegression()
model_lr_cut.fit(x_cut, y_cut)

plt.plot(x, model_lr.predict(x), linestyle="solid")
plt.plot(x, model_lr_cut.predict(x), linestyle="solid")
plt.plot(lit_h_back, color = "red")
plt.show()

print('モデル関数の回帰変数 w1: %.3f' %model_lr.coef_)
print('モデル関数の切片 w2: %.3f' %model_lr.intercept_)
print('y= %.3fx + %.3f' % (model_lr.coef_ , model_lr.intercept_))
print('決定係数 R^2: ', model_lr.score(x, y))
print('')
print('モデル関数の回帰変数 w1: %.3f' %model_lr_cut.coef_)
print('モデル関数の切片 w2: %.3f' %model_lr_cut.intercept_)
print('y= %.3fx + %.3f' % (model_lr_cut.coef_ , model_lr.intercept_))
print('決定係数 R^2: ', model_lr_cut.score(x, y))
# Out:
# モデル関数の回帰変数 w1: 0.208
# モデル関数の切片 w2: 14.564
# y= 0.208x + 14.564
# 決定係数 R^2:  0.944870616007594
#
# モデル関数の回帰変数 w1: 0.235
# モデル関数の切片 w2: 12.712
# y= 0.235x + 14.564
# 決定係数 R^2:  0.9235943643912523

# %%
lit_yiq  = [colorsys.rgb_to_yiq(r[0]/255, r[1]/255, r[2]/255) for r in iron_palet]

lit_y = [r[0] for r in lit_yiq]
lit_i = [r[1] for r in lit_yiq]
lit_q = [r[2] for r in lit_yiq]

plt.plot(lit_y, color = "red")
plt.plot(lit_i, color = "green")
plt.plot(lit_q, color = "blue")
plt.show()

# %%
lit_y_430 = [r[0]*430 for r in lit_yiq]

x = np.array(range(len(lit_y_430))).reshape(-1,1)
y = np.array(lit_y_430).reshape(-1,1)
model_lr = LinearRegression()
model_lr.fit(x, y)

plt.plot(x, model_lr.predict(x), linestyle="solid")
plt.plot(lit_y_430, color = "red")
plt.show()

print('モデル関数の回帰変数 w1: %.3f' %model_lr.coef_)
print('モデル関数の切片 w2: %.3f' %model_lr.intercept_)
print('y= %.3fx + %.3f' % (model_lr.coef_ , model_lr.intercept_))
print('決定係数 R^2: ', model_lr.score(x, y))
# Out:
# モデル関数の回帰変数 w1: 0.971
# モデル関数の切片 w2: -6.951
# y= 0.971x + -6.951
# 決定係数 R^2:  0.9947909949625401

# %%
lit_hls  = [colorsys.rgb_to_hls(r[0]/255, r[1]/255, r[2]/255) for r in iron_palet]

lit_h = [r[0]*360 for r in lit_hls]
lit_l = [r[1]*100 for r in lit_hls]
lit_s = [r[2]*100 for r in lit_hls]

plt.plot(lit_h, color = "red")
plt.plot(lit_l, color = "green")
plt.plot(lit_s, color = "blue")
plt.show()
